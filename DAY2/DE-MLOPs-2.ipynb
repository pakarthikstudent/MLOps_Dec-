# %%
products={}
products['pid']=[101,102,103]
products['pname']=['pA','pB','pC']
products['pcost']=[1000,2000,3000]

products['pid'].append(104)
products['pname'].append('pD')
products['pcost'].append(4000)


products['pid'].append(105)
products['pname'].append('pE')
products['pcost'].append(5000)

products['pid'].append(106)
products['pname'].append('pF')
products['pcost'].append(6000)


products['pid'].append(107)
products['pname'].append('pG')
products['pcost'].append(7000)

products['pid'].append(108)
products['pname'].append('pF')
products['pcost'].append(8000)
products
# Out:
# {'pid': [101, 102, 103, 104, 105, 106, 107, 108],
#  'pname': ['pA', 'pB', 'pC', 'pD', 'pE', 'pF', 'pG', 'pF'],
#  'pcost': [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]}

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(products)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     8 non-null      int64
#  1   pname   8 non-null      object
#  2   pcost   8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
df1.loc[2:4][['pname','pcost']]
# Out:
#   pname  pcost
# 2    pC   3000
# 3    pD   4000
# 4    pE   5000

# %%
df1.drop(columns='pcost')
# Out:
#    pid pname
# 0  101    pA
# 1  102    pB
# 2  103    pC
# 3  104    pD
# 4  105    pE
# 5  106    pF
# 6  107    pG
# 7  108    pF

# %%
df1.drop(columns=['pcost','pname'])
# Out:
#    pid
# 0  101
# 1  102
# 2  103
# 3  104
# 4  105
# 5  106
# 6  107
# 7  108

# %%
df1
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000
# 6  107    pG   7000
# 7  108    pF   8000

# %%
## rename columns
#----------------
# df.rename({'oldColumnName':'newColumn'})
d={'K1':[1,2,3],'K2':[4,3,1],'Field 3':[10,20,30]}

df2 = pd.DataFrame(d)
df2.columns
# Out:
# Index(['K1', 'K2', 'Field 3'], dtype='object')

# %%
df2.rename(columns={'Field 3':'K3'})
# Out:
#    K1  K2  K3
# 0   1   4  10
# 1   2   3  20
# 2   3   1  30

# %%
df2.rename(columns={'Field 3':'K3'},inplace=True)

# %%
df2.columns
# Out:
# Index(['K1', 'K2', 'K3'], dtype='object')

# %%
## Null value - missing values ->NaN 
d={}
d['K1'] = [10,20,None]
d['K2'] = [15,None,None]
d['K3'] = [None,11,None]
pd.DataFrame(d)
# Out:
#      K1    K2    K3
# 0  10.0  15.0   NaN
# 1  20.0   NaN  11.0
# 2   NaN   NaN   NaN

# %%
df3 = pd.DataFrame(d)
df3.info()
df3.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   K1      2 non-null      float64
#  1   K2      1 non-null      float64
#  2   K3      1 non-null      float64
# dtypes: float64(3)
# memory usage: 204.0 bytes
#       K1     K2     K3
# 0  False  False   True
# 1  False   True  False
# 2   True   True   True

# %%
df3.isnull().sum()
# Out:
# K1    1
# K2    2
# K3    2
# dtype: int64

# %%
# To replace NaN Value => fillna(<replacementValue>)
df3.fillna('TestData')
# Out:
#          K1        K2        K3
# 0      10.0      15.0  TestData
# 1      20.0  TestData      11.0
# 2  TestData  TestData  TestData

# %%
df3.fillna(45)
# Out:
#      K1    K2    K3
# 0  10.0  15.0  45.0
# 1  20.0  45.0  11.0
# 2  45.0  45.0  45.0

# %%
df3
# Out:
#      K1    K2    K3
# 0  10.0  15.0   NaN
# 1  20.0   NaN  11.0
# 2   NaN   NaN   NaN

# %%
df3['K1']
# Out:
# 0    10.0
# 1    20.0
# 2     NaN
# Name: K1, dtype: float64

# %%
df3['K1'].fillna(44)
# Out:
# 0    10.0
# 1    20.0
# 2    44.0
# Name: K1, dtype: float64

# %%
df3[['K2','K3']].fillna(56.31)
# Out:
#       K2     K3
# 0  15.00  56.31
# 1  56.31  11.00
# 2  56.31  56.31

# %%
df3.fillna(56.31,inplace=True)

# %%
df3.isnull().sum()
# Out:
# K1    0
# K2    0
# K3    0
# dtype: int64

# %%
## duplicate data
df3.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
print(df3.duplicated().sum())
# Out:
# 0

# %%
d={'K1':[10,10,30],'K2':[10,10,30],'K3':[10,10,30]}
df4 = pd.DataFrame(d)
df4.duplicated().sum()
# Out:
# np.int64(1)

# %%
df4.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
df4.drop_duplicates()
# Out:
#    K1  K2  K3
# 0  10  10  10
# 2  30  30  30

# %%
df4
# Out:
#    K1  K2  K3
# 0  10  10  10
# 1  10  10  10
# 2  30  30  30

# %%
# df.at[row,colum]='update_value'

df4.loc[1]['K2']
# Out:
# np.int64(10)

# %%
df4.at[1,'K2'] = 3456.23
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_1536\3143748350.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3456.23' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df4.at[1,'K2'] = 3456.23

# %%
df4
# Out:
#    K1       K2  K3
# 0  10    10.00  10
# 1  10  3456.23  10
# 2  30    30.00  30

# %%
## Write DataFrame to FILE => df.to_csv(resultFile)
df4.to_csv('test1.csv')

# %%
pd.read_csv('emp.csv')  Vs pd.DataFrame(<datastructure>)
# Out:
#    eid    ename  edept    ecity  ecost
# 0  101      raj  sales     pune   1000
# 1  102      leo   prod   bglore   2301
# 2  230      raj   prod     pune   2300
# 3  450     shan  sales   bglore   3401
# 4  542      anu     HR   mumbai   4590
# 5  321     bibu  sales      hyd   5419
# 6  651      ram     hr   bglore   3130
# 7  541      leo  admin  chennai   4913
# 8  652  karthik  sales   bglore   3405

# %%
# df4.to_csv('test1.csv')
pd.read_csv('test1.csv')
# Out:
#    Unnamed: 0  K1       K2  K3
# 0           0  10    10.00  10
# 1           1  10  3456.23  10
# 2           2  30    30.00  30

# %%
df4.to_csv('test1.csv',index=False)
pd.read_csv('test1.csv')
# Out:
#    K1       K2  K3
# 0  10    10.00  10
# 1  10  3456.23  10
# 2  30    30.00  30

# %%
# 1. load the data ->dataframe
df_csv = pd.read_csv('emp.csv')
# 2. Get information about the data
df_csv.info()
# 3. List of row index and columns 
print(df_csv.index)
print(df_csv.columns)
# 4. display shape of the data -> Row X Col
print(df_csv.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   eid     9 non-null      int64
#  1   ename   9 non-null      object
#  2   edept   9 non-null      object
#  3   ecity   9 non-null      object
#  4   ecost   9 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 492.0+ bytes
# RangeIndex(start=0, stop=9, step=1)
# Index(['eid', 'ename', 'edept', 'ecity', 'ecost'], dtype='object')
# (9, 5)

# %%
df3.to_csv('test1.log',sep=":")

# %%
pd.read_csv('test1.log')
# Out:
#              :K1:K2:K3
# 0    0:10.0:15.0:56.31
# 1    1:20.0:56.31:11.0
# 2  2:56.31:56.31:56.31

# %%
pd.read_csv('test1.log',sep=':')
# Out:
#    Unnamed: 0     K1     K2     K3
# 0           0  10.00  15.00  56.31
# 1           1  20.00  56.31  11.00
# 2           2  56.31  56.31  56.31

# %%
# Test - anyduplicated values are exists
df_csv.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_csv.drop_duplicates(inplace=True)

# %%
df_csv.columns
# Out:
# Index(['eid', 'ename', 'edept', 'ecity', 'ecost'], dtype='object')

# %%
df_csv.rename(columns={'edept':'EDEPT','ecost':'Amount'},inplace=True)

# %%
df_csv
# Out:
#    eid    ename  EDEPT    ecity  Amount
# 0  101      raj  sales     pune    1000
# 1  102      leo   prod   bglore    2301
# 2  230      raj   prod     pune    2300
# 3  450     shan  sales   bglore    3401
# 4  542      anu     HR   mumbai    4590
# 5  321     bibu  sales      hyd    5419
# 6  651      ram     hr   bglore    3130
# 7  541      leo  admin  chennai    4913
# 8  652  karthik  sales   bglore    3405

# %%
len(df_csv.index)
# Out:
# 9

# %%
for var in range(1,len(df_csv.index)+1):
    print(var,end=' ')
# Out:
# 1 2 3 4 5 6 7 8 9

# %%
df_csv.index=[var for var in range(1,len(df_csv.index)+1)]

# %%
df_csv.index
# Out:
# Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64')

# %%
df_csv
# Out:
#    eid    ename  EDEPT    ecity  Amount
# 1  101      raj  sales     pune    1000
# 2  102      leo   prod   bglore    2301
# 3  230      raj   prod     pune    2300
# 4  450     shan  sales   bglore    3401
# 5  542      anu     HR   mumbai    4590
# 6  321     bibu  sales      hyd    5419
# 7  651      ram     hr   bglore    3130
# 8  541      leo  admin  chennai    4913
# 9  652  karthik  sales   bglore    3405

# %%
df_csv.sort_index()
# Out:
#    eid    ename  EDEPT    ecity  Amount
# 1  101      raj  sales     pune    1000
# 2  102      leo   prod   bglore    2301
# 3  230      raj   prod     pune    2300
# 4  450     shan  sales   bglore    3401
# 5  542      anu     HR   mumbai    4590
# 6  321     bibu  sales      hyd    5419
# 7  651      ram     hr   bglore    3130
# 8  541      leo  admin  chennai    4913
# 9  652  karthik  sales   bglore    3405

# %%
df_csv.sort_index(ascending=False)
# Out:
#    eid    ename  EDEPT    ecity  Amount
# 9  652  karthik  sales   bglore    3405
# 8  541      leo  admin  chennai    4913
# 7  651      ram     hr   bglore    3130
# 6  321     bibu  sales      hyd    5419
# 5  542      anu     HR   mumbai    4590
# 4  450     shan  sales   bglore    3401
# 3  230      raj   prod     pune    2300
# 2  102      leo   prod   bglore    2301
# 1  101      raj  sales     pune    1000

# %%
df_csv.sort_values(by='ecity')
# Out:
#    eid    ename  EDEPT    ecity  Amount
# 2  102      leo   prod   bglore    2301
# 4  450     shan  sales   bglore    3401
# 7  651      ram     hr   bglore    3130
# 9  652  karthik  sales   bglore    3405
# 8  541      leo  admin  chennai    4913
# 6  321     bibu  sales      hyd    5419
# 5  542      anu     HR   mumbai    4590
# 1  101      raj  sales     pune    1000
# 3  230      raj   prod     pune    2300

# %%
Data Aggregation
================
Rage of data //array ----->------scalar data(single)

np.max([1,1,23,145,4323433,34]) ---> 4323433

np.max()
np.min()
np.mean()
np.sum()
..
df.groupby('field').sum()|max()|min()|mean()|count()....

# %%
products = {'pnames':['pA','pB','pA','pC','pB','pD'],
            'sales':[100,200,140,120,110,120]}

df = pd.DataFrame(products)
df.groupby('pnames').sum()
# Out:
#         sales
# pnames
# pA        240
# pB        310
# pC        120
# pD        120

# %%
df.groupby('pnames').min()
# Out:
#         sales
# pnames
# pA        100
# pB        110
# pC        120
# pD        120

# %%
df.groupby('pnames').agg(['min','max'])
# Out:
#        sales
#          min  max
# pnames
# pA       100  140
# pB       110  200
# pC       120  120
# pD       120  120

# %%
Python     ---------------   <DB-Module> ------------- DB
 DS                                                    SQL
"insert into ..."                                      select *from ...-->result
"select *from .."                                                            |
-------------------//str                                                     |
                               -----------<---------------------------------
                                       python -undestanding format

# %%
import sqlite3

# %%
sqlite3.connect("demo1.db")

# %%
conn = sqlite3.connect("demo1.db")
conn.cursor()

# %%
sth = conn.cursor()
sth.execute('create table product(id INT,pname TEXT,pcost REAL)')

# %%
sth.execute("insert into product(id,pname,pcost) values (101,'pA',1000)")

# %%
sth.execute("insert into product(id,pname,pcost) values (101,'pA',1000)")

# %%
 sth.execute("select *from product")

# %%
list(sth) # generator
# Out:
# [(101, 'pA', 1000.0), (102, 'pB', 2000.0)]

# %%
va = 103
vb = 'pC'
vc = 3000
sth.execute("insert into product(id,pname,pcost) values (?,?,?)",(va,vb,vc))

# %%
sth.execute("insert into product(id,pname,pcost) values (105,'pD',4300)")

# %%
conn.commit()

# %%
myconn = sqlite3.connect("demo1.db")
sth = myconn.cursor()
sth.execute("select *from product")

# %%
list(sth)
# Out:
# [(101, 'pA', 1000.0),
#  (102, 'pB', 2000.0),
#  (103, 'pC', 3000.0),
#  (105, 'pD', 4300.0)]

# %%
pd.read_sql_query("select *from product",myconn)
# Out:
#     id pname   pcost
# 0  101    pA  1000.0
# 1  102    pB  2000.0
# 2  103    pC  3000.0
# 3  105    pD  4300.0

# %%
# Extract-Transform-Load (ETL)
Data - Extracted from Datasource(File,API,DB,..) -->Transfomed(Clean;Aggregation..) -->Load to the target

# Extract-Load-Transformed (ELT)

# %%
# Create products.csv file and write product details(pid,pname,pcost)
|
df
|
df.to_csv('product.csv')
|
ETL 
# Read this CSV file - Extract
# pcost - apply tax # Transform
# Load - create a new database file
#  |->df.to_sql()

# %%
products={}
products['pid']=[101,102,103,104,105]
products['pname']=['pA','pB','pC','pD','pE']
products['pcost']=[1000,2000,3000,4000,5000]

df_product = pd.DataFrame(products)
df_product.to_csv("products.csv",index=False)

# %%
df_prod = pd.read_csv('products.csv') # Extract
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     5 non-null      int64
#  1   pname   5 non-null      object
#  2   pcost   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
# Transform
df_prod['pcost'] = df_prod.apply(lambda a: a['pcost'] * 12.0 if a['pname'] == 'pC' else a['pcost'],axis=1)
df_prod
# Out:
#    pid pname    pcost
# 0  101    pA   1000.0
# 1  102    pB   2000.0
# 2  103    pC  36000.0
# 3  104    pD   4000.0
# 4  105    pE   5000.0

# %%
# Load 
con = sqlite3.connect("products_etl.db")
df_prod.to_sql('product',con,if_exists='replace',index=False)
# Out:
# 5

# %%
# Testing
list(con.execute("select *from product"))
# Out:
# [(101, 'pA', 1000.0),
#  (102, 'pB', 2000.0),
#  (103, 'pC', 36000.0),
#  (104, 'pD', 4000.0),
#  (105, 'pE', 5000.0)]

# %%
con.close()

# %%
## ELT
## . 1. Extract product.csv data from file
##   2. Load same product.csv data 
##   3. Transform - use SQL

# Extract
df_prod = pd.read_csv('products.csv')
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     5 non-null      int64
#  1   pname   5 non-null      object
#  2   pcost   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
# Load 
conn = sqlite3.connect("product_1.db")
df_prod.to_sql("product_raw",conn,if_exists='replace',index=False)
# Out:
# 5

# %%
# Transform(inside the db) - inside the db via SQL not using python programming

conn.execute("""create table product_final as 
                select pid,
                       pname,
                       pcost,
                       CASE
                         when pname == 'pC' THEN pcost * 18
                         ELSE pcost 
                       END AS pcost
                      FROM product_raw;
                      """)
conn.commit()

# %%
list(conn.execute("select *from product_final"))
# Out:
# [(101, 'pA', 1000, 1000),
#  (102, 'pB', 2000, 2000),
#  (103, 'pC', 3000, 54000),
#  (104, 'pD', 4000, 4000),
#  (105, 'pE', 5000, 5000)]

# %%
numpy - computing
pandas - analysis 
---------
matplotlib - visualization
==========
 |->matplotlib/
           |->pyplot/
                |----->plot() sctter() ...

# %%
import matplotlib.pyplot as plt
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.plot([1,3,5,6,7],[10,15,2,12,35])

# %%
plt.figure(figsize=(1,2))
plt.plot([1,3,5,6,7],[10,15,2,12,35])

# %%
plt.figure(figsize=(5,3))
plt.plot([1,3,5,6,7],[10,15,2,12,35],marker='o')

# %%
plt.figure(figsize=(5,3))
plt.scatter([1,3,5,6,7],[10,15,2,12,35])

# %%
#help(plt.plot)

# %%
plt.figure(figsize=(5,3))
plt.scatter([1,3,5,6,7],[10,15,2,12,35])
plt.title("prodA sales report:-")
plt.xlabel("Sales Count")
plt.ylabel("Cost")
# Out:
# Text(0, 0.5, 'Cost')

# %%
plt.figure(figsize=(5,3))
d = np.arange(0,5,0.1)
X = np.arange(0,5,0.1)
Y = np.sin(2*np.pi*d)
plt.plot(X,Y,'ro--')

d = np.arange(0,5,0.1)
X = np.arange(0,5,0.1)
Y = np.sin(2*np.pi*d)
plt.plot(X,Y,'bo--')

# %%
subplot
 |->subplot(X,Y,index) -> 1 2 3 .. N <== position

plt.subplot(1,2,1) --->same as plt.subplot(121)
plt.subpolot(2,2,1) --->same as plt.subplot(221)

# %%
plt.figure(figsize=(5,3))
d = np.arange(0,5,0.1)
X = np.arange(0,5,0.1)
Y = np.sin(2*np.pi*d)
plt.subplot(2,1,1)
plt.plot(X,Y,'ro--')

d = np.arange(0,5,0.1)
X = np.arange(0,5,0.1)
Y = np.sin(2*np.pi*d)
plt.subplot(2,1,2)
plt.plot(X,Y,'bo--')

# %%
plt.bar(['pA','pB','pC'],[1000,250,2450])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(['pA','pB','pC'],[1000,250,2450])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(['pA','pB','pC'],[1000,250,2450],width=0.3,color='green')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(['pA','pB','pC'],[1000,250,2450],height=0.3,color='green')
# Out:
# <BarContainer object of 3 artists>

# %%
# boxplot 
# -------
pcost = [100,200,300,400,6000,500,700]
plt.boxplot(pcost)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228b81e5090>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x228b81e5310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x228b81e4f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x228b81e5590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228b81e56d0>],
#  'means': []}

# %%
pcost = [100,200,300,400,500,700]
plt.boxplot(pcost)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228b83fc910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x228b83fcb90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x228b83fc7d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x228b83fce10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228b83fcf50>],
#  'means': []}

# %%
import seaborn
1. visualization - based on matplotlib
2. pre-defined datasets

# %%
import seaborn as sns
#help(sns.load_dataset)
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = sns.load_dataset('tips')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
plt.scatter(df['total_bill'],df['tip'])

# %%
1. numerical data plot
     relplot() scatterplot() lineplot()
2. categorical data plot
     catplot(),boxplot()
3. distribution of data
  kdeplot() displot()
4. Linear Regression
      regplot()

# %%
# plt.scatter(df['total_bill'],df['tip'])
sns.relplot(x='total_bill',y='tip',data=df,hue='smoker')

# %%
sns.relplot(x=df_csv['ename'],y=df_csv['Amount'],data=df_csv,hue='EDEPT')

# %%
plt.box() - visualization
sns.box() - visualization 

Zscore 
           X - mean of the dataset
Zscore =   ------------------------
             std deviation

X - datapoint
2 3 ..

# %%
d=np.array([50,60,70,80,90])
mean = np.mean(d)
std_dev = np.std(d)

zscore = (d - mean) / std_dev
zscore
# Out:
# array([-1.41421356, -0.70710678,  0.        ,  0.70710678,  1.41421356])

# %%
d[np.abs(zscore) >2]
# Out:
# array([], dtype=int64)

# %%
plt.boxplot(d)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228bab66d50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x228bab66fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x228bab66c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x228bab67250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228bab67390>],
#  'means': []}

# %%
d=np.array([50,60,70,80,90,100,110,150,1200,160])
mean = np.mean(d)
std_dev = np.std(d)

zscore = (d - mean) / std_dev
zscore
# Out:
# array([-0.47182902, -0.44177622, -0.41172342, -0.38167061, -0.35161781,
#        -0.321565  , -0.2915122 , -0.17130098,  2.98424345, -0.14124818])

# %%
plt.boxplot(d)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228bac2b750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x228bac2b9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x228bac2b610>],
#  'medians': [<matplotlib.lines.Line2D at 0x228bac2bc50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228bac2bd90>],
#  'means': []}

# %%
#### EDA
Understand data structure , types , shape,identify missing values,outliner 
find relationshiops between features

1. Data Collection
2. Data Inspection - df.info()
3. Descriptive statistics - mean,median,mode,variance ..
|
4. Univariate analysis 
    - single value 
      ---------------//distribution of a single value
      productName
      productCost
      productMarketingCost
      productSalesCount

    Bivariate analysis
     - two variables 

     productName Vs productCost
     productCost Vs ProductMarketingCost
     ...
     Multivariate analysis - 3 or more than 3
      [marketingCost][productName][SalesCount] 
      --->visualization =>sns.pairplot
          ..

LoadData -->Clean -->EDA --->Visualization
Pandas                 
Numpy
Matplotlib,Seborn
Pandas Profiling ..

# %%
df = sns.load_dataset('tips')

from pandas_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_file("tips_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
EDA = Understand Data + DataRelationShip + Visualize Patterns

LoadData -->Clean -->EDA --->Visualization ====> ML
|-----------------------------------------|

# %%
df_tips = sns.load_dataset('tips')
df_tips.isnull().sum()
#df_tips.info()
df_tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.pairplot(df_tips,vars=['total_bill','tip'],hue='smoker')

# %%
## Activity
##
Load the data - https://github.com/pakarthikstudent/MLOps_Dec-/blob/main/DataSets/used_cars_data.csv
|
Get Info about the data  ===>df_prod.shape -> (7000,25)
|
Apply random sampling => df.random(n=<Count>)  => ex: df_prod.random(n=50) 
|
|->See - 1st 3 lines from sample data
|->Get list of columns
|->Test - any duplicate items are exists -->drop_duplicates
|->Test - any null value -->replace NaN value ->avg of data
|->Rename -->some fields
|->Test - outlier 
|->Apply Aggregate method - based on the data fields => mean,max..
|->EDA
     |->Visualization
=========================================================================================================================

# %%
Data Pipeline
typically performs
 --> Ingestion - Data Collection - Kakfa,Flume,Sqoop,NiFi
 --> processing - PySpark,pandas (batch data)
 --> Storage  - Hadoop,S3,Snowflake,...

 --> Monitoring ->Continuous Monitoring ..

Batch - stored data 
Real-Time/Streaming  - Kafaka,Spark Streaming
#################################################################

pd.read_csv('input_data.csv') 

File: input_data.csv - 5GB size
      (batch type)
Working Resource RAM size:2GB
------------------------------------//? 

file: calltrack.log - live stream data
      ...
      200 lines - 15:41 time
pd.read_csv('calltract.log',sep=":").shape ->(200,15) ->15:41

pd.read_csv('calltract.log',sep=":").shape ->(250,15) ->15:51
--------------------------------------------------------------//?
|
|
Go to PySpark 
=============

HDFS - Hadoop Distributed File System
-------------------------==============

OS - FileSystem
-----------------

    +----------------------
    | User: editor - write/read // plain data
    +----------|-----------
    | OS(Kernel)
    |      |->FileSystem(data structure) - holding info about data - meta data
    |            meta data- <index - sector_range + permission_details>
    +----------------------
    | H/W: HD (raw data)
    +--------------------------


HDFS
-----
 |->meta data - filename,index,block location..

emp.csv
========
 |->block1
 |->block2
     ..
 |->blockN

Enduser -> [edge_node] -------------->[master_node - metadata]
                                               |
                                             slave_node1 .. slave_nodeN 
1. Master - Slave
2. Peer to Peer 

1. Master - Slave

    [ MasterNode ]  - SPOC
       |   - meta_data
       ClientAPICall()
       |       |   |_________________
       |       |___                  |
    SlaveNode1    SlaveNode2    .. SlaveNodeN //block data


1GB -> 16block 

[slaveNode1]  [slaveNode2] [slaveNode3]
B0 B1 B2      B1 B2 B5       B0 B2 B5


2. Peer to Peer 
[node1] <====>[node2]
    |__[node3]___|
all the nodes are connected 

HADOOP - Storage layer

spark = apache spark
Python+Spark = PySpark
    
Spark
- Batch processing 
- Streaming data
    +
- ML
- Graph 
PySpark - distributed computing

PySpark
- JVM + HADOOP + Python

python 3.10 - 3.12 /OK

SparkSession Object
    |
    Configure
    |
    builder
    |
    AppName 
    |
    Create an object
    
Load Data ->Data Partition -->Transformation ->Action
                                 |               |->Spark executes the DAG executors 
                                DAG

import SparkSessionModule
          |->Configuration builder
                     |->AppName |->Master |->otherConfig ...

from pyspark.sql import SparkSession
SparkSession.builder.appName("etl").getOrCreate() ->sparksession_object


Spark SQL
-------------
Delta Lake
-----------------------
Data Storage(HDFS/S3)

# %%
In Pandas DataFrame
----------------------
pd.DataFrame(<dataStructure>) ->display (action)
Vs
In Pyspark DataFrame
--------------------
df = spark.createDataFrame(<datastructure>+<schema>) //transformation
df.show() //action


pd.read_csv('emp.csv')
|
|
spark.read.csv('emp.csv')

L=[1,2,3,4,5,6]
-------------------// cpu-core1 
Vs
L=[1,2,3,4,5,6]
----------------//cpu-core1 cpu-core2 cpu-core3..cpu-core8

L=[1,2,3,4,5]
|
RDD([1,2,3,4,5],3)
P1: [1,2]
P2: [3,4]
P3: [5]

File ->map ->filter ->display

Reference: https://spark.apache.org/docs/latest/rdd-programming-guide.html#parallelized-collections

# %%
############# End of the Day2 Session #############
